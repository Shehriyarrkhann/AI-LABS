# %% [markdown]
# <a href="https://colab.research.google.com/github/Shehriyarrkhann/AI-LABS/blob/main/MIN_MAX_ALGO_IMPLEMENTATION_05_05_2026_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **QUESTION 02**

# %%
import math

# Minimax function
def minimax(depth, nodeIndex, isMax, values, maxDepth):

    # Base case: leaf node
    if depth == maxDepth:
        return values[nodeIndex]

    if isMax:
        return max(
            minimax(depth + 1, nodeIndex * 2, False, values, maxDepth),
            minimax(depth + 1, nodeIndex * 2 + 1, False, values, maxDepth)
        )
    else:
        return min(
            minimax(depth + 1, nodeIndex * 2, True, values, maxDepth),
            minimax(depth + 1, nodeIndex * 2 + 1, True, values, maxDepth)
        )


# Example leaf nodes (from your board)
values = [-4, -5, 2, 3, 4, 5, 6, 7]

# Tree depth = log2(n)
depth = int(math.log2(len(values)))

result = minimax(0, 0, True, values, depth)

print("Optimal Value (Minimax):", result)
# Out:
# Optimal Value (Minimax): 5

# %% [markdown]
# # **QUESTION 01**

# %%
def minimax(node, is_max, graph, values):

    # If leaf node → return its value
    if node not in graph:
        return values[node]

    children = graph[node]

    if is_max:
        best = float("-inf")
        for child in children:
            best = max(best, minimax(child, False, graph, values))
        return best

    else:
        best = float("inf")
        for child in children:
            best = min(best, minimax(child, True, graph, values))
        return best


# ---------------- GRAPH (FULL 3 LEVEL TREE) ----------------
graph = {
    "A": ["B", "C"],

    "B": ["D", "E"],
    "C": ["F", "G"],

    "D": ["H", "I"],
    "E": ["J", "K"],
    "F": ["L", "M"],
    "G": ["N", "O"]
}

# ---------------- LEAF VALUES (LEVEL 3) ----------------
values = {
    "H": 3,
    "I": 5,
    "J": -2,
    "K": 4,
    "L": 6,
    "M": 1,
    "N": -3,
    "O": 2
}

# ---------------- RUN MINIMAX ----------------
result = minimax("A", True, graph, values)

print("Result:", result)
# Out:
# Result: 4

# %% [markdown]
# # **Question 03**

# %%
# #QUESTIONS IN CODE

# # Q3: Create Important Questions from Code (at least 20)

# # Here are 20 strong, exam-ready questions based on YOUR code:

# # 📌 Conceptual + Code-Based Questions
# # What is Minimax algorithm?
# # What problem does Minimax solve?
# # What are MAX and MIN players?
# # Why recursion is used in Minimax?
# # What is a terminal (leaf) node?
# # What is depth of a tree?
# # What is nodeIndex used for?
# # Why nodeIndex * 2 is used?
# # Why nodeIndex * 2 + 1 is used?
# # What is base condition in Minimax code?
# # How does MAX choose values?
# # How does MIN choose values?
# # What is time complexity of Minimax?
# # What is space complexity?
# # What is a complete binary tree?
# # Why log₂(n) is used for depth?
# # What happens if tree is not complete?
# # Can Minimax work without recursion?
# # Where is Minimax used in real life?
# # What are limitations of Minimax?


















# 📌 1. What is Minimax algorithm?

# A decision-making algorithm used in two-player games to choose the best move by minimizing the opponent’s maximum gain.

# 📌 2. What problem does Minimax solve?

# It solves optimal move selection in adversarial games like tic-tac-toe, chess, etc.

# 📌 3. What are MAX and MIN players?
# MAX: tries to maximize score
# MIN: tries to minimize MAX’s score
# 📌 4. Why recursion is used in Minimax?

# Because the algorithm explores a tree of future moves recursively until leaf nodes.

# 📌 5. What is a terminal (leaf) node?

# A node with no children; represents final game state with a score.

# 📌 6. What is depth of a tree?

# Number of levels from root to the deepest leaf node.

# 📌 7. What is nodeIndex used for?

# It represents position of a node in an array-based binary tree.

# 📌 8. Why nodeIndex * 2 is used?

# To move to the left child in a binary tree representation.

# 📌 9. Why nodeIndex * 2 + 1 is used?

# To move to the right child in a binary tree representation.

# 📌 10. What is base condition in Minimax code?

# When a node is a leaf node, return its value.

# 📌 11. How does MAX choose values?

# It selects the maximum value from child nodes.

# 📌 12. How does MIN choose values?

# It selects the minimum value from child nodes.

# 📌 13. What is time complexity of Minimax?

# O(b^d) where:

# b = branching factor
# d = depth




# 📌 14. What is space complexity?

# O(d) due to recursion stack.

# 📌 15. What is a complete binary tree?

# A tree where all levels are fully filled except possibly the last.

# 📌 16. Why log₂(n) is used for depth?

# Because in a binary tree, depth grows logarithmically with number of nodes.

# 📌 17. What happens if tree is not complete?

# Depth and branching become irregular, making computation less predictable.

# 📌 18. Can Minimax work without recursion?

# Yes, using iteration and stacks, but recursion is simpler and more common.

# 📌 19. Where is Minimax used in real life?
# Chess engines
# Tic-tac-toe
# AI decision systems
# Game theory problems



# 📌 20. What are limitations of Minimax?
# Very slow for large trees
# High computation cost
# Needs pruning (Alpha-Beta) for efficiency

# %% [markdown]
# # **Question 04**

# %%
#### SYNTAX OF MIN MAX ALGORITHM

def minimax(node, is_max, graph, values):
    # Assuming 'terminal' nodes are those not in the graph
    if node not in graph:
        return values[node]


    children = graph[node]

    if is_max:
        best = float('-inf')
        for child in children:
            best = max(best, minimax(child, False, graph, values))
        return best



    else:
        best = float('inf')
        for child in children:
            best = min(best, minimax(child, True, graph, values))
        return best

# %% [markdown]
# # **TASK**

# %% [markdown]
# # **QUESTION 01 & 02**

# %%
import math

def alpha_beta(node, depth, alpha, beta, is_maximizing, tree, leaf_values):
    # Base case: leaf node
    if node not in tree:
        return leaf_values[node]

    children = tree[node]

    if is_maximizing:
        max_eval = -math.inf
        for child in children:
            eval = alpha_beta(child, depth + 1, alpha, beta, False, tree, leaf_values)
            max_eval = max(max_eval, eval)
            alpha = max(alpha, eval)
            if beta <= alpha:
                print(f"  Pruning at node {child} (β={beta} ≤ α={alpha})")
                break  # β cut-off
        return max_eval
    else:
        min_eval = math.inf
        for child in children:
            eval = alpha_beta(child, depth + 1, alpha, beta, True, tree, leaf_values)
            min_eval = min(min_eval, eval)
            beta = min(beta, eval)
            if beta <= alpha:
                print(f"  Pruning at node {child} (β={beta} ≤ α={alpha})")
                break  # α cut-off
        return min_eval


# Tree structure (adjacency list)
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['n1', 'n2'],
    'E': ['n3', 'n4'],
    'F': ['n5', 'n6'],
    'G': ['n7', 'n8'],
}

# Leaf node values
leaf_values = {
    'n1': 4, 'n2': 3,
    'n3': 2, 'n4': 10,
    'n5': 1, 'n6': 4,
    'n7': 4, 'n8': 5
}

result = alpha_beta('A', 0, -math.inf, math.inf, True, tree, leaf_values)
print(f"\nOptimal Value: {result}")
# Out:
#   Pruning at node n4 (β=4 ≤ α=10)
#   Pruning at node F (β=4 ≤ α=4)
#
# Optimal Value: 4

# %% [markdown]
# # **QUESTION 03**

# %%
# 20 Important Questions with Answers (Alpha-Beta Pruning)

# What is Alpha-Beta Pruning? — An optimization of Minimax that eliminates branches that can't affect the final decision.
# What is the α value? — The best value the MAX player can guarantee so far.
# What is the β value? — The best value the MIN player can guarantee so far.
# When is a branch pruned? — When β ≤ α.
# What game does Minimax model? — Two-player, zero-sum games.
# What is the time complexity of Minimax? — O(b^d), where b = branching factor, d = depth.
# What is best-case time complexity of Alpha-Beta? — O(b^(d/2)) — effectively doubles search depth.
# What is worst-case complexity of Alpha-Beta? — O(b^d) — same as Minimax (no pruning happens).
# What causes α cut-off? — At a MIN node, if a child's value ≤ α, prune remaining children.
# What causes β cut-off? — At a MAX node, if a child's value ≥ β, prune remaining children.
# Does Alpha-Beta change the final result? — No, it always returns the same result as Minimax.
# What is the initial value of α? — −∞
# What is the initial value of β? — +∞
# Who benefits from move ordering? — Alpha-Beta — better ordering = more pruning.
# What is a terminal node? — A leaf node with a known utility/heuristic value.
# What does MAX player try to do? — Maximize the score.
# What does MIN player try to do? — Minimize the score.
# Is Alpha-Beta complete? — Yes, on finite trees.
# Where is Alpha-Beta used in real life? — Chess engines (Stockfish), Checkers, Go.
# What is the difference between α and β? — α belongs to MAX (lower bound), β belongs to MIN (upper bound).












# 📌 1. What is Alpha-Beta Pruning?

# An optimization of Minimax that skips branches that cannot influence the final decision.

# 📌 2. What is the α value?

# Best (highest) value MAX can guarantee so far.

# 📌 3. What is the β value?

# Best (lowest) value MIN can guarantee so far.

# 📌 4. When is a branch pruned?

# When β ≤ α.

# 📌 5. What game does Minimax model?

# Two-player, zero-sum games.

# 📌 6. What is time complexity of Minimax?

# O(b^d)

# 📌 7. Best-case complexity of Alpha-Beta?

# O(b^(d/2))

# 📌 8. Worst-case complexity of Alpha-Beta?

# O(b^d) (no pruning)

# 📌 9. What causes α cut-off?

# At MIN node, if value ≤ α, stop exploring further.

# 📌 10. What causes β cut-off?

# At MAX node, if value ≥ β, stop exploring further.

# 📌 11. Does Alpha-Beta change result?

# No, same result as Minimax.

# 📌 12. Initial value of α?

# −∞

# 📌 13. Initial value of β?

# +∞

# 📌 14. Who benefits from move ordering?

# Alpha-Beta pruning (better ordering = more pruning).

# 📌 15. What is a terminal node?

# A leaf node with a final score (utility value).

# 📌 16. What does MAX do?

# Tries to maximize score.

# 📌 17. What does MIN do?

# Tries to minimize score.

# 📌 18. Is Alpha-Beta complete?

# Yes, for finite game trees.

# 📌 19. Where is it used?

# Chess engines like Stockfish, AI games, decision systems.

# 📌 20. Difference between α and β?
# α = MAX’s best lower bound
# β = MIN’s best upper bound
