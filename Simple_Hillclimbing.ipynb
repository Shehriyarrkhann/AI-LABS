# %% [markdown]
# <a href="https://colab.research.google.com/github/Shehriyarrkhann/AI-LABS/blob/main/Simple_Hillclimbing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **QUESTION 02**

# %%
# Simple Hill Climbing Algorithm

def objective_function(x):
    # Function to maximize
    return -(x - 5) ** 2 + 25


def hill_climbing(start, step_size, max_iterations):

    current = start
    current_value = objective_function(current)

    print("Starting Point:", current)
    print("Starting Value:", current_value)

    for i in range(max_iterations):

        # Generate neighbors
        left = current - step_size
        right = current + step_size

        # Evaluate neighbors
        left_value = objective_function(left)
        right_value = objective_function(right)

        # Move to better neighbor
        if left_value > current_value:
            current = left
            current_value = left_value

        elif right_value > current_value:
            current = right
            current_value = right_value

        else:
            # No better neighbor found
            break

        print(f"Iteration {i+1}: x = {current}, f(x) = {current_value}")

    return current, current_value


# Parameters
start_point = 0
step = 1
iterations = 20

# Run Algorithm
best_x, best_value = hill_climbing(start_point, step, iterations)

print("\nBest Solution Found:")
print("x =", best_x)
print("Maximum Value =", best_value)
# Out:
# Starting Point: 0
# Starting Value: 0
# Iteration 1: x = 1, f(x) = 9
# Iteration 2: x = 2, f(x) = 16
# Iteration 3: x = 3, f(x) = 21
# Iteration 4: x = 4, f(x) = 24
# Iteration 5: x = 5, f(x) = 25
#
# Best Solution Found:
# x = 5
# Maximum Value = 25

# %% [markdown]
# # **QUESTION 03**

# %% [markdown]
# # **Important Questions about the code**

# %%
# # 1	What is Hill Climbing?
# Hill Climbing is a local search optimization algorithm used to find the best solution step by step.
# # 2	Which type of algorithm is Hill Climbing?
# It is a heuristic search algorithm.
# # 3	What is the main goal of Hill Climbing?
# To maximize or minimize an objective function.
# # 4	What is an objective function?
# A mathematical function used to evaluate solution quality.
# # 5	What does the algorithm start with?
# It starts with an initial state or starting point.
# # 6	What is a neighbor state?
# A nearby possible solution generated from the current state.
# # 7	What is step size in the code?
# It defines how far the algorithm moves in one iteration.
# # 8	Why do we use max iterations?
# To prevent infinite looping.
# # 9	What happens if no better neighbor is found?
# The algorithm stops.
# # 10	Is Hill Climbing complete?
# No, it may fail to find the global optimum.
# # 11	What is local maximum?
# A solution better than nearby states but not the best overall solution.
# # 12	What is global maximum?
# The best possible solution in the entire search space.
# # 13	What is the weakness of Hill Climbing?
# It can get stuck in local maxima.
# # 14	What is a heuristic?
# A technique that helps solve problems faster using practical methods.
# # 15	What is the role of the objective function in our code?
# It calculates the quality of each solution.
# # 16	Which function was used in the code?
# f(x)=−(x−5)2+25
# # 17	At which value does the function become maximum?
# At x=5
# # 18	Why do we compare neighbors?
# To move toward a better solution.
# # 19	What data type stores the current value?
# Integer or float variables.
# # 20	Where is Hill Climbing used in real life?
# Robotics, AI, route optimization, scheduling, and machine learning.
